# %%
import os
repo = 'boston-marathons'
counter = 0
max_depth = 50
current = os.getcwd()
while True:
    current_tmp = os.path.basename(os.getcwd())
    if current_tmp == repo:
        print(f"Main dir found: {os.getcwd()}")
        break
    else:
        os.chdir("..")
        counter += 1
        if counter >= max_depth:
            print(f"Reached {max_depth} levels up — '{repo}' not found.")
            os.chdir(current)
            print(f"Current path: {current}")
            break
# Out:
# Main dir found: D:\Scripts\Data Science\projekty\repo\boston-marathons

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
from scripts.mappings import continent_colors

# %%
df = pd.read_csv('./data/clean/boston_features.csv')
df.head()
# Out:
#                     Name M/F  Age Age Group Country      Continent  \
# 0         Desisa, Lelisa   M   25     22–25     ETH         Africa
# 1        Kirui, Geoffrey   M   24     22–25     KEN         Africa
# 2  Tsegay, Yemane Adhane   M   30     30–33     ETH         Africa
# 3            Rupp, Galen   M   30     30–33     USA  North America
# 4         Chebet, Wilson   M   29     26–29     KEN         Africa
#
#           City      Pace        5K       10K       15K       20K       25K  \
# 0         Ambo  3.065431  0.245278  0.495278  0.749167  1.008056  1.268611
# 1     Keringet  3.075787  0.256944  0.507778  0.762222  1.020833  1.283056
# 2  Addis Ababa  3.086144  0.245278  0.495278  0.749444  1.007778  1.268611
# 3     Portland  3.086144  0.256667  0.507500  0.762222  1.020833  1.283056
# 4     Marakwet  3.096500  0.245278  0.495278  0.749167  1.008056  1.268611
#
#         30K       35K       40K  Official Time  Year  Place_Year  Place_Global
# ...

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
# fig
fig, ax = plt.subplots(figsize=(8,8))
# subset
subset = df[['Age', 'Pace', 'Continent']]
subset = subset.groupby(['Age', 'Continent']).mean().reset_index()

# create plot
for continent, color in continent_colors.items():
    data = subset[subset['Continent'] == continent]
    # xy
    x = data['Age']
    y = data['Pace']
    # color
    c = color
    # alpha
    a = 1 if continent == 'Asia' else .5
    # scatterplot
    ax.scatter(x, y, color=c, label=continent, s=50, alpha=a)

## xy settings
# x
ax.set_xlabel('Age', weight='bold')
ax.set_xticks(np.arange(20,86,5))
# y
ax.set_ylabel('Pace', weight='bold')
ax.set_yticks(np.arange(3,9,.5))
ax.invert_yaxis()

# style
ax.set_title('Average Running Pace by Age and Continent', weight='bold')
ax.grid(True, linestyle='--', alpha=.5)
ax.legend(loc='upper right', bbox_to_anchor=(1.3,1), fontsize=12)
ax.spines[['top','bottom','left','right']].set_visible(False)

# plt.savefig('test/chart_14.png', dpi=300, bbox_inches='tight')
plt.show()
